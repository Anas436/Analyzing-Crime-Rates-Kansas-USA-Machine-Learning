# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv('merged_kansas_state_2007_2020_NaN_not_filled.csv').iloc[:, 1:]

print(df)

crimes = df['Type'].unique()

#print(crimes)
colors = ['red', 'green', 'blue', 'yellow', 'orange', 'gray', 'black', 'purple', 'pink', 'brown']

for crime in crimes:
    fig = plt.figure(figsize=[20, 15])
    color_index = 0
    crime_to_plot = pd.DataFrame()
    for row in df[df['Type'] == crime].index:
        #print(row)
        crime_to_plot = pd.concat([crime_to_plot,
                                   pd.DataFrame({df.iloc[row, -1]: df.iloc[row, 1:-1]})], axis=1)
    
    #print(crime, crime_to_plot)
    sns.lineplot(crime_to_plot, linestyle='solid').set_title(crime)

    plt.show()
# Out:
#            Type     2007     2008     2009     2010     2011     2012
# 0       Murders      1.0      3.0      0.0      2.0      1.0      1.0  \
# 1         Rapes     19.0     28.0     34.0     25.0     22.0     26.0
# 2     Robberies     22.0     21.0     23.0     35.0     28.0     24.0
# 3      Assaults    187.0    220.0    206.0    184.0    183.0    211.0
# 4    Burglaries    432.0    468.0    417.0    589.0    503.0    503.0
# ..          ...      ...      ...      ...      ...      ...      ...
# 85   Burglaries   4362.0   4081.0   4054.0   4248.0   4017.0   3949.0
# 86       Thefts  14296.0  14132.0  13928.0  12515.0  13615.0  15466.0
# 87  Auto thefts   2139.0   1865.0   1674.0   1537.0   1908.0   1832.0
# 88        Arson    189.0    187.0    180.0    129.0    139.0    134.0
# 89  Crime Index    564.1    521.5    511.6    459.2    470.9    480.6
#
#        2013     2014     2015     2016     2017     2018     2019     2020
# 0       3.0      0.0      1.0      2.0      2.0      1.0      1.0      0.0  \
# 1      43.0     32.0     43.0     35.0     40.0     37.0     26.0     11.0
# 2      27.0     21.0     26.0     24.0     36.0     18.0     20.0      4.0
# 3     182.0    152.0    186.0    126.0    165.0    115.0    107.0     66.0
# 4     437.0    381.0    261.0    431.0    429.0    360.0    260.0     79.0
# ..      ...      ...      ...      ...      ...      ...      ...      ...
# 85   3941.0   3264.0   3489.0   3470.0   3296.0   3420.0   2674.0   2427.0
# 86  14930.0  13006.0  14178.0  15417.0  15943.0  15988.0  15937.0  13321.0
# 87   1989.0   2031.0   2052.0   2202.0   2492.0   2785.0   2318.0   2072.0
# 88    113.0    120.0    129.0    136.0    100.0    139.0    127.0    132.0
# 89    483.8    447.0    534.7    558.4    572.7    612.5    576.8    557.9
#
#      City name
# 0   Hutchinson
# 1   Hutchinson
# 2   Hutchinson
# 3   Hutchinson
# 4   Hutchinson
# ..         ...
# 85     Wichita
# 86     Wichita
# 87     Wichita
# 88     Wichita
# 89     Wichita
#
# [90 rows x 16 columns]
